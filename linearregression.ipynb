# %% [markdown]
# # linear regression

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error, mean_squared_log_error, median_absolute_error, explained_variance_score ,max_error  
from sklearn.preprocessing import StandardScaler

# %%
import plotly as px

# %%
# load the dataset tips
tips = sns.load_dataset('tips')

# %%
sns.scatterplot(data=tips, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
tips.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 tips.columns()
#
# TypeError: 'Index' object is not callable

# %%
# split the data into X and y
X = tips[['total_bill']]
y = tips['tip']

# %%
# split the data into train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
# call the model
m1 = LinearRegression()

# %%
# train the model
m1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# predict
y_pred = m1.predict(X_test)

# %%
# take out the intercept and slope of the model make an equation out of it
print(m1.intercept_)
print(m1.coef_)
print(m1.score(X_test, y_test))
# print( 'y = ' {} + {}x'.format(m1.intercept_, m1.coef_))
# Out:
# 1.029018329780312
# [0.0980155]
# 0.4758502665396157

# %%
m1.predict(44)
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 m1.predict(44)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:386, in LinearModel.predict(self, X)
#     372 def predict(self, X):
#     373     """
#     374     Predict using the linear model.
#     375
#    (...)
#     384         Returns predicted values.
#     385     """
# --> 386     return self._decision_function(X)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:369, in LinearModel._decision_function(self, X)
#     366 def _decision_function(self, X):
# ...

# %%
# evaluate the model
print('MSE=' mean_squared_error(y_test, y_pred))
print('MAE=' mean_absolute_error(y_test, y_pred))
print('R2=' r2_score(y_test, y_pred))
print('explained variance=' explained_variance_score(y_test, y_pred))
print('max error=' max_error(y_test, y_pred))
print('median absolute error=' median_absolute_error(y_test, y_pred))
print('mean squared log error=' mean_squared_log_error(y_test, y_pred))
print('RMSE=', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
#   Cell In[23], line 2
#     print('MSE=' mean_squared_error(y_test, y_pred))
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print('MSE=', mean_squared_error(y_test, y_pred))
print('MAE=', mean_absolute_error(y_test, y_pred))
print('R2=', r2_score(y_test, y_pred))
print('explained variance=', explained_variance_score(y_test, y_pred))
print('max error=', max_error(y_test, y_pred))
print('median absolute error=', median_absolute_error(y_test, y_pred))
print('mean squared log error=', mean_squared_log_error(y_test, y_pred))
print('RMSE=', np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# MSE= 1.4967669998789983
# MAE= 0.9074307972086088
# R2= 0.4758502665396157
# explained variance= 0.48362951904731644
# max error= 3.9908139434029115
# median absolute error= 0.6646455530808209
# mean squared log error= 0.06793847034990068
# RMSE= 1.2234242926634236

# %%
# plot the model
plt.scatter(y_test, y_pred)

# %%
# plot the model using seaborn
sns.regplot(x=y_test, y=y_pred)
# Out:
# <Axes: xlabel='tip'>

# %%
# plot the model in a better way
plt.figure(figsize=(10, 6))
sns.regplot(x=y_test, y=y_pred)
# Out:
# <Axes: xlabel='tip'>

# %%
# plot the model in even a better way
plt.figure(figsize=(10, 6))
sns.regplot(x=y_test, y=y_pred)
plt.title('Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
# plot the model in even a better way
plt.figure(figsize=(10, 6))
sns.regplot(x=y_test, y=y_pred)
plt.title('Total Bill vs Tip')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.show()

# %%
plt.scatter(X_test, y_test)
plt.plot(X_test, y_pred, color='red')

# %%
Z = tips[['total_bill']]
scaler = StandardScaler()
scaler.fit(Z)
Z = scaler.transform(Z)
w = tips['tip']

# %%
m1.fit(Z_train, w_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 m1.fit(Z_train, w_train)
#
# NameError: name 'Z_train' is not defined

# %%
from sklearn.preprocessing import StandardScaler

# %%
Z_train, Z_test, w_train, w_test = train_test_split(Z, w, test_size=0.2, random_state=42)

# %%
w_pred = m1.predict(Z_test)
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(Z_test, w_test)
plt.plot(Z_test, w_pred, color='red')

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, Normalizer, MaxAbsScaler, QuantileTransformer, PowerTransformer, KBinsDiscretizer

# %%
minmax = MinMaxScaler()
Q = tips[['total_bill','size']]
p = tips['tip']
minmax.fit(Q)
# Out:
# MinMaxScaler()

# %%
Q_train, Q_test, p_train, p_test = train_test_split(Z, y, test_size=0.2, random_state=42)

# %%
p_pred = m1.predict(Q_test)
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(Q_test, p_test)
plt.plot(Q_test, p_pred, color='red')

# %%
# regression on titanic dataset
ship = sns.load_dataset('titanic')

# %%
# simple linear regression
from sklearn.linear_model import LinearRegression

# %%
ship.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
X = ship[['age']]
y = ship['fare']

# %%
X.isnull().sum() / len(X) * 100
# Out:
# age    19.86532
# dtype: float64

# %%
y.isnull().sum() / len(y) * 100
# Out:
# 0.0

# %%
X['age'] = X['age'].fillna(value=X['age'].mean())
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14248\2408138173.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X['age'] = X['age'].fillna(value=X['age'].mean())

# %%
X.isnull().sum()
# Out:
# age    0
# dtype: int64

# %%
X.shape
# Out:
# (891, 1)

# %%
ship_linear = ship[['age','fare']]

# %%
y.shape
# Out:
# (891,)

# %%
# lm plot
sns.lmplot(ship_linear['age','fare'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('age', 'fare')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 2
#       1 # lm plot
# ...

# %%
sns.lmplot(data=ship, x='age', y='fare',color='red', height=6, aspect=1.5)

# Display the plot
plt.title("Linear Relationship between Age and Fare")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 sns.lmplot(data=ship, x='age', y='fare',color='red', height=6, aspect=1.5)
#       3 # Display the plot
#       4 plt.title("Linear Relationship between Age and Fare")
#
# TypeError: lmplot() got an unexpected keyword argument 'color'

# %%
sns.lmplot(data=ship, x='age', y='fare', height=6, aspect=1.5)

# Display the plot
plt.title("Linear Relationship between Age and Fare")
plt.show()

# %%
ship_linear['age'] = ship_linear['age'].fillna(value=ship_linear['age'].mean())
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14248\3452620777.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ship_linear['age'] = ship_linear['age'].fillna(value=ship_linear['age'].mean())

# %%
sns.lmplot(data=ship_linear, x='age', y='fare', height=6, aspect=1.5)

# Display the plot
plt.title("Linear Relationship between Age and Fare")
plt.show()

# %%
ship_linear.isnull().sum()
# Out:
# age     0
# fare    0
# dtype: int64

# %%
# box plot
sns.boxplot(data=ship_linear, x='age')
# Out:
# <Axes: xlabel='age'>

# %%
sns.boxplot(data=ship_linear, y='age')
# Out:
# <Axes: ylabel='age'>

# %%
ship_linear = ship_linear[(ship_linear['age'] > 5) & (ship_linear['age'] < 55)]

# %%
sns.boxplot(data=ship_linear, y='age')
# Out:
# <Axes: ylabel='age'>

# %%
ship_linear = ship_linear[(ship_linear['age'] > 8) & (ship_linear['age'] < 50)]

# %%
sns.boxplot(data=ship_linear, y='age')
# Out:
# <Axes: ylabel='age'>

# %%
ship_linear = ship_linear[(ship_linear['age'] > 8) & (ship_linear['age'] < 48)]

# %%
sns.boxplot(data=ship_linear, y='age')
# Out:
# <Axes: ylabel='age'>

# %%
ship_linear = ship_linear[(ship_linear['fare']  < 75)]

# %%
sns.boxplot(data=ship_linear, y='fare')
# Out:
# <Axes: ylabel='fare'>

# %%
ship_linear = ship_linear[(ship_linear['fare']  < 60)]

# %%
sns.boxplot(data=ship_linear, y='fare')
# Out:
# <Axes: ylabel='fare'>

# %%
ship_linear = ship_linear[(ship_linear['fare']  < 40)]

# %%
sns.boxplot(data=ship_linear, y='fare')
# Out:
# <Axes: ylabel='fare'>

# %%
X = ship_linear[['age']]
y = ship_linear['fare']

# %%
sns.lmplot(data=ship_linear, x='age', y='fare', height=6, aspect=1.5)

# Display the plot
plt.title("Linear Relationship between Age and Fare")
plt.show()

# %%
model = LinearRegression()

# %%
# train the model
model.fit(X,y)
# Out:
# LinearRegression()

# %%
model.predict([[25]])
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([13.24504419])

# %%
model.predict([[65]])
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([18.35319041])

# %%
model.predict([[82]])
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([20.52415255])

# %%
# evaluate the model
# r2
# mean square error (MSE)
# root mean square error (RMSE)
# MAE
X_train,X_test,y_train,y_test = train_test_split(X,y, train_size=0.8)

# %%
X.shape
# Out:
# (610, 1)

# %%
X_test.shape
# Out:
# (122, 1)

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([13.07410875, 13.69598901, 13.69598901, 13.69598901, 14.71088914,
#        13.94705829, 13.69598901, 14.05617698, 13.94705829, 13.69598901,
#        14.82000783, 14.16529567, 15.58383868, 12.85587136, 13.69598901,
#        13.40146483, 13.69598901, 13.51058352, 13.40146483, 12.85587136,
#        15.58383868, 14.60177044, 13.69598901, 12.74675267, 14.38353306,
#        12.52851529, 13.94705829, 12.85587136, 11.43732836, 12.41939659,
#        13.18322744, 15.42016064, 11.43732836, 14.27441437, 13.69598901,
#        13.69598901, 14.05617698, 13.69598901, 13.8379396 , 13.69598901,
#        12.85587136, 12.85587136, 13.69598901, 14.38353306, 13.69598901,
#        14.16529567, 13.94705829, 14.38353306, 12.85587136, 13.8379396 ,
#        11.87380313, 13.69598901, 13.69598901, 13.40146483, 13.94705829,
#        13.40146483, 12.96499006, 12.85587136, 13.69598901, 13.51058352,
#        12.52851529, 13.69598901, 13.69598901, 13.69598901, 13.51058352,
# ...

# %%
prediction = model.predict(X_test)

# %%
# compare
sns.scatterplot(x=y_test, y= prediction)
# Out:
# <Axes: xlabel='fare'>

# %%
model.score(X_test,y_test)
# Out:
# 0.0175689726019006

# %%
X.head()
# Out:
#          age
# 0  22.000000
# 2  26.000000
# 4  35.000000
# 5  29.699118
# 8  27.000000

# %%
from sklearn.metrices import mean_squared_error
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 from sklearn.metrices import mean_squared_error
#
# ModuleNotFoundError: No module named 'sklearn.metrices'
